# %%
from Library import Multiplefunction

# %%
Multiplefunction.SubfieldsInAI()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# ['Machine Learning',
#  'Neural Networks',
#  'Vision',
#  'Robotics',
#  'Speech Processing',
#  'Natural Language Processing']

# %%
Multiplefunction.OddEven()
# Out:
# Enter a number: 52452
# 52452 is Even number
# 'Even number'

# %%
Multiplefunction.agelimit()
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE
# 'NOT ELIGIBLE'

# %%
Multiplefunction.percentage()
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total : 468
# Percentage:  93.60000000000001

# %%
Multiplefunction.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
